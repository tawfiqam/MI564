# %% [markdown]
# <a href="https://colab.research.google.com/github/tawfiqam/MI564/blob/main/MI_564_Example_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Most of the time, your dataset will be saved as a csv or a json file (this specifically is important for API's which we will discuss in detail next week). This [is the file](https://drive.google.com/file/d/1NGtj9Ceg74WrYNVaFQdgIfDBwHdA9IJ-/view?usp=sharing) we are using today.
#
# There are two ways to do this on Colab:
#
# 1.   Upload the file and use it as though it is local
# 2.   Mount the drive and get file
#
# We will do both today.

# %% [markdown]
# First, select a file by clicking on the the upload icon to the left side of your screen
#
# ![Slide5.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd

# %%
df = pd.read_csv('nba.csv')

# %% [markdown]
# Or....we could read it from our own Google Drive account
# First, you'll have to upload the file to your Google Drive folder

# %%
#You need to run this code to load data from the Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/MachineLearning:17:610:564:90/Examples/nba.csv')

# %% [markdown]
# OK...now that we showed how to read a csv file in two different ways, let's think about what we can do with it...

# %%
#Get the first four rows by index
df.iloc[0:4]
# Out:
#             Name            Team  Number  ... Weight            College     Salary
# 0  Avery Bradley  Boston Celtics     0.0  ...  180.0              Texas  7730337.0
# 1    Jae Crowder  Boston Celtics    99.0  ...  235.0          Marquette  6796117.0
# 2   John Holland  Boston Celtics    30.0  ...  205.0  Boston University        NaN
# 3    R.J. Hunter  Boston Celtics    28.0  ...  185.0      Georgia State  1148640.0
#
# [4 rows x 9 columns]

# %% [markdown]
# OK. Now, I want to split the dataframe by team and get mean, min, and max value of age for each team.
#
# By this I mean that I want to see the mean, minimum and maximum age of players for each team

# %%
grouped_single = df.groupby('Team').agg({'Age': ['mean', 'min', 'max']})
grouped_single
# Out:
#                               Age
#                              mean   min   max
# Team
# Atlanta Hawks           28.200000  22.0  35.0
# Boston Celtics          24.733333  20.0  29.0
# Brooklyn Nets           25.600000  21.0  32.0
# Charlotte Hornets       26.133333  21.0  31.0
# Chicago Bulls           27.400000  21.0  35.0
# Cleveland Cavaliers     29.533333  24.0  35.0
# Dallas Mavericks        29.733333  22.0  37.0
# Denver Nuggets          25.733333  20.0  36.0
# Detroit Pistons         26.200000  20.0  36.0
# Golden State Warriors   27.666667  20.0  33.0
# Houston Rockets         26.866667  22.0  38.0
# Indiana Pacers          26.400000  20.0  30.0
# Los Angeles Clippers    29.466667  23.0  39.0
# Los Angeles Lakers      27.533333  20.0  37.0
# Memphis Grizzlies       28.388889  21.0  39.0
# Miami Heat              28.933333  20.0  36.0
# Milwaukee Bucks         24.562500  19.0  32.0
# Minnesota Timberwolves  26.357143  20.0  40.0
# ...
